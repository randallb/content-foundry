// %%
import openAi, { runIt } from "experimental/aiYC.ts"

// %%
await runIt(JSON.stringify({
  companySummary: "AI-first open-source replacement for WordPress",
  productSummary: "Initially, we’ve built a tool which helps people create and edit blog posts to match a consistent voice. Users start by either pasting links to content they find inspirational or manually explaining their voice. They can then paste in a blog post and our system will recommend ways to improve their writing, including voice / tone, but also other storytelling best-practices like active voice, three-act structure, and inverted pyramid.We intend this product to be the first step toward a much broader vision. We’re building an open-source platform designed to help content creators (and companies) tell their story at scale across all mediums and platforms. We’re confident it would replace tools like WordPress.",
  locationDecision:"The company is based in NYC because it’s where we had the highest concentration of people when we started, but we intend to always be a distributed, remote team. ",
  progress:"We launched a prototype on Hacker News today (2/7) and are beginning to build a developer community around the OSS. We currently work with two design partners, AstroForge (W22) and Pattern, paying us 12k and 3k / mo, respectively.",
  workLengthHistory: "We wrote the first lines of code in April 2023. We’ve all been working on it full-time since November 2023.",
  techStack: "Deno + Postgres + React + Graphql + Isograph",
  revenueSource: "Currently revenue comes from design partners, AstroForge and Pattern.",
  previousApplicationChange: "Our original hypothesis was too narrow. From working with customers and building products we learned that knowing *what* to create is a bigger problem than *how* to create it. Getting started and figuring out what kind of content to make is a core issue for businesses—especially startups—pursuing a content marketing strategy. After deciding what content to create, tooling is rarely the problem. And the market for creating better / shorter videos isn’t big enough to support the kind of company we want to build.",
  otherIncubators: "N/A",
  reasonForProductChoice: "We are video producers, creators, and musicians who have worked together for years helping people make better content. At Vidpresso (W14) we became a team; at Facebook we built products at scale; now at Content Foundry, we want to work with our best friends building products to help people do something we’ve devoted our lives to: Telling great stories. We’ve spent the last year and a half talking to different customer segments, building prototypes, and pivoting away from things that weren’t working. We know technical founders at seed and series A startups don’t typically understand mass media, and they know their startup’s growth is dependent on stories spreading organically to other potential customers. They are willing to pay to fix this problem.",
  competitors: "Our initial product competes with something like Grammarly or Jasper. But unlike pure writing assistants that focus only on generating text, we integrate the entire content lifecycle, from crafting the core company story and creating content, to publication and analytics. In the long term we compete with open-source CMS providers like WordPress, Strapi, Ghost, etc. While WordPress and similar systems are fundamentally CMSs, we’re building an OS for content. In a post-LLM world there are richer experiences that can exist if we start from a blank slate. As an AI-native content operating system, we fill the gap for a platform that generates and manages content in one place.",
  moneyMaking: "We’ll follow the WordPress model of charging for a cloud hosted version of our open-source software. Content creation and management is a multi-billion dollar space when you include marketing, publishing, etc. WordPress powers roughly half of the Internet. We’re starting with targeting technical founders at seed and series A startups to refine the product before expanding to new markets.",
  otherIdeas: "?",
  equityBreakdown: "Randall Bennett, CEO - 16%, Justin Carter, Software Engineer - 16%, Josh LeVitre, Software Engineer - 16%, George LeVitre, Software Engineer - 16%, Dan Sisco, COO - 16%, Equity Pool - 20%",
  investmentsReceived: "",
  reasonForAppling: "",
  whoToldYou: "",
    }))
// Out:
// {
//   companySummary: {
//     revision: "Open-source AI platform for content creation",
//     explanation: "The revised summary is more concise and focuses on the core aspect of the company, which is the open-source AI platform for content creation. This aligns with the successful example and provides a clearer understanding of the company's focus.",
//     confidence: 0.9
//   },
//   productSummary: {
//     revision: "We are developing an open-source AI platform that assists content creators in producing and managing content across various mediums. Our initial tool helps users create and edit blog posts to maintain a consistent voice, offering recommendations for improvements in tone and storytelling techniques. This is the first step towards a comprehensive platform designed to replace traditional CMS tools like WordPress, enabling scalable storytelling for content creators and companies.",
//     explanation: "The revised description provides a clearer and more structured overview of the product, highlighting its unique features and long-term vision. It aligns with the successful example by emphasizing the product's capabilities and future potential.",
//     confidence: 0.95
//   },
//   locationDecision: {
//     revision: "We are based in NYC due to the initial concentration of our team, but we plan to remain a remote-first company to leverage talent from around the world.",
//     explanation: "The revision clarifies the reason for the location choice and emphasizes the company's remote-first approach, which aligns with modern startup practices and the successful example.",
//     confidence: 0.85
//   },
//   progress: {
//     revision: "We launched a prototype on Hacker News today (2/7) and are actively building a developer community around our open-source platform. We currently have two design partners, AstroForge and Pattern, generating $12k and $3k per month, respectively.",
//     explanation: "The revised progress section provides a concise update on the prototype launch and partnerships, highlighting revenue generation and community building, which are key indicators of progress.",
//     confidence: 0.9
//   },
//   workLengthHistory: {
//     revision: "We began writing code in April 2023 and have been working full-time on the project since November 2023.",
//     explanation: "The revision clarifies the timeline of work and emphasizes the full-time commitment of the team, aligning with the successful example's focus on dedication and progress.",
//     confidence: 0.9
//   },
//   techStack: {
//     revision: "Our tech stack includes Deno, Postgres, React, GraphQL, and Isograph for developing our open-source AI platform.",
//     explanation: "The revision presents the tech stack in a clear and concise manner, similar to the successful example, highlighting the technologies used in building the platform.",
//     confidence: 0.85
//   },
//   revenueSource: {
//     revision: "Our current revenue comes from our design partners, AstroForge and Pattern, who are paying us for using our platform.",
//     explanation: "The revision clearly states the current revenue sources, aligning with the successful example by specifying the partners and the nature of the revenue.",
//     confidence: 0.9
//   },
//   previousApplicationChange: {
//     revision: "We initially focused on content creation tools but realized through customer feedback that identifying content to create is a bigger challenge. Our pivot addresses this by providing a comprehensive content strategy and management platform, learning from our initial narrow focus.",
//     explanation: "The revision provides a clear explanation of the pivot, focusing on customer feedback and lessons learned, similar to the successful example's emphasis on iterative learning and adaptation.",
//     confidence: 0.9
//   },
//   otherIncubators: {
//     revision: "We have not participated in or committed to any other incubators.",
//     explanation: "The revision clearly states the lack of involvement with other incubators, aligning with the successful example's straightforward approach to this question.",
//     confidence: 0.95
//   },
//   reasonForProductChoice: {
//     revision: "As experienced video producers and content creators, we identified a gap in the market for a comprehensive content management platform. Our background in storytelling and product development at Vidpresso and Facebook gives us unique insights into the needs of content creators and startups.",
//     explanation: "The revision highlights the founders' relevant experience and market insight, similar to the successful example's emphasis on domain expertise and understanding of customer needs.",
//     confidence: 0.9
//   },
//   competitors: {
//     revision: "Our initial competitors include writing assistants like Grammarly and Jasper, but our long-term vision positions us against open-source CMS providers like WordPress. Unlike them, we offer an AI-native platform that integrates content creation, management, and analytics, filling a gap in the current market.",
//     explanation: "The revision clearly identifies competitors and differentiates the product, aligning with the successful example's focus on competitive advantage and market positioning.",
//     confidence: 0.9
//   },
//   moneyMaking: {
//     revision: "We plan to monetize by offering a cloud-hosted version of our open-source platform, similar to WordPress. The content creation and management market is vast, and we aim to capture a significant share by initially targeting technical founders at startups.",
//     explanation: "The revision outlines a clear monetization strategy and market potential, similar to the successful example's approach to describing revenue models and market opportunity.",
//     confidence: 0.9
//   },
//   otherIdeas: {
//     revision: "We considered various content creation tools but ultimately focused on building a comprehensive content management platform due to its broader market potential.",
//     explanation: "The revision provides a brief overview of other ideas considered, aligning with the successful example's approach to discussing alternative concepts.",
//     confidence: 0.85
//   },
//   equityBreakdown: {
//     revision: "Randall Bennett, CEO - 16%, Justin Carter, Software Engineer - 16%, Josh LeVitre, Software Engineer - 16%, George LeVitre, Software Engineer - 16%, Dan Sisco, COO - 16%, with a 20% equity pool for future employees.",
//     explanation: "The revision clearly outlines the equity distribution, similar to the successful example's transparent approach to sharing ownership details.",
//     confidence: 0.95
//   },
//   investmentsReceived: {
//     revision: "We have not yet received any external investments.",
//     explanation: "The revision clearly states the current investment status, similar to the successful example's straightforward approach to discussing funding.",
//     confidence: 0.95
//   },
//   reasonForAppling: {
//     revision: "We believe Y Combinator can significantly accelerate our growth by providing unparalleled mentorship and access to a network of successful entrepreneurs. We are eager to leverage YC's resources to refine our product and expand our market reach.",
//     explanation: "The revision provides a clear reason for applying to YC, emphasizing the benefits of mentorship and networking, which aligns with the successful example's focus on YC's value proposition.",
//     confidence: 0.9
//   },
//   whoToldYou: {
//     revision: "We learned about Y Combinator through industry colleagues and have been inspired by the success stories of previous YC alumni.",
//     explanation: "The revision provides a straightforward explanation of how the team learned about YC, similar to the successful example's approach to this question.",
//     confidence: 0.85
//   }
// }
